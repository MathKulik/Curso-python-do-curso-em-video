# %%
from random import choice

jok=['pedra', 'papel', 'tesoura']
esc=choice(jok)
p1=str(input('me fala algum dos 3'))

#vitoria
if p1=='pedra' and esc=='tesoura':
    print('ganhou')
elif p1=='tesoura' and esc=='papel':
    print('ganhou')
elif p1=='papel' and esc=='pedra':
    print('ganhei')
#vitoria
elif p1=='pedra' and esc=='pedra':
    print('empate')
elif p1=='papel' and esc=='papel':
    print('empate')
elif p1=='tesoura' and esc=='tesoura':
    print('empate')
else:
    print('perdeu')
# Out:
# me fala algum dos 3 pedra
# perdeu
