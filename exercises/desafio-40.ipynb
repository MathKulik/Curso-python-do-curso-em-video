# %%
n1=float(input('me fala a primeira nota '))
n2=float(input('me fala a segunda nota '))
n=n1+n2/2
if n<5:
    print('reprovado')
elif n>=5 and n<=6.9:
    print('recuperação')
else:
    print('aprovado')
