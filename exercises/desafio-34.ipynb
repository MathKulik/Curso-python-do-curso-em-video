# %%
sal=int(input('me fala seu salario'))
if sal>1250:
    x=sal*0.10
    res=x+sal
    print('seu novo salario é {}' .format(res))
else:
    x=sal*0.15
    res=x+sal
    print('seu novo salario é {}'.format(res))
