# %%
cas=float(input('me fala o valor da casa '))
sal=float(input('me fala o seu salario '))
ano=int(input('me fala em quantos anos vai pagar '))
val=cas/(ano*12)
vl=sal*0.3

if val<=vl:
    print('foi aprovado, a prestação é de {}')
else:
    print('ta tudo negado')
# Out:
# me fala o valor da casa  120000
# me fala o seu salario  1250
# me fala em quantos anos vai pagar  10
# ta tudo negado
